# %%
import h5py as h5
import json

# %%
f = h5.File("/home/vignesh2496/CMU/Spring-19/Courses/10-707/Project/Baseline/VQA_LSTM_CNN/data_prepro.h5", "r")

# %%
f.keys()
# Out:
# <KeysViewHDF5 ['MC_ans_test', 'answers', 'img_pos_test', 'img_pos_train', 'ques_length_test', 'ques_length_train', 'ques_test', 'ques_train', 'question_id_test', 'question_id_train']>

# %%
len(f['answers'])
# Out:
# 215359

# %%
with open('../../data_train-val_test/data_prepro.json', 'r') as file:
    obj = json.load(file)
    print(obj.keys())
    for key in obj.keys():
        print(obj[key].__class__)
# Out:
# dict_keys(['unique_img_test', 'ix_to_ans', 'unique_img_train', 'ix_to_word'])
# <class 'list'>
# <class 'dict'>
# <class 'list'>
# <class 'dict'>

# %%
print(obj['ix_to_word'])
# Out:
# {'3716': 'saver', '571': 'incense', '4528': 'absent', '10432': 'radiant', '1084': 'weather-vane', '14145': 'footstool', '6800': 'hippopotami', '11460': 'gowns', '6512': 'wii', '13363': 'reflection', '3022': 'clasping', '9428': 'footboards', '2272': 'kreme', '3488': 'toshiba', '2895': 'bird', '13795': 'crane', '3077': 'dispose', '6131': 'grant', '7481': 'vodka', '3655': 'frequency', '318': 'pumpkins', '11769': 'cycle', '13557': 'slots', '9': 'hanging', '2902': 'gathered', '7443': 'right-', '3780': 'established', '2515': 'cages', '8102': 'popular', '1028': 'crashing', '9670': 'serena', '6848': 'crate', '2417': 'muted', '13436': 'favorable', '7438': 'arms', '11401': 'washer', '4733': 'losing', '13469': 'whistle', '9618': 'needle', '14115': 'contemplative', '12419': 'officials', '2133': 'brown/tan', '13656': 'spurs', '1824': 'an', '6952': 'shingle', '13830': 'riot', '3016': 'delay', '3689': 'ponytail', '3272': 'monitors/screens', '6005': 'catcher', '12394': 'convention', '6230': 'front-m
# ...

# %%
with open('/home/vignesh2496/CMU/Spring-19/Courses/10-707/Project/Baseline/VQA/Annotations/mscoco_train2014_annotations.json', 'r') as file:
    ques = json.load(file)
print(ques['annotations'][0])
# Out:
# {'question_id': 4870250, 'question_type': 'what', 'answers': [{'answer_id': 1, 'answer': 'oval', 'answer_confidence': 'yes'}, {'answer_id': 2, 'answer': 'semi circle', 'answer_confidence': 'yes'}, {'answer_id': 3, 'answer': 'curved', 'answer_confidence': 'yes'}, {'answer_id': 4, 'answer': 'curved', 'answer_confidence': 'yes'}, {'answer_id': 5, 'answer': 'double curve', 'answer_confidence': 'yes'}, {'answer_id': 6, 'answer': 'banana', 'answer_confidence': 'maybe'}, {'answer_id': 7, 'answer': 'curved', 'answer_confidence': 'yes'}, {'answer_id': 8, 'answer': 'wavy', 'answer_confidence': 'yes'}, {'answer_id': 9, 'answer': 'twisting', 'answer_confidence': 'no'}, {'answer_id': 10, 'answer': 'curved', 'answer_confidence': 'maybe'}], 'answer_type': 'other', 'image_id': 487025, 'multiple_choice_answer': 'curved'}
